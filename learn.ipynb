# %%
import regex as re
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
re.findall(PAT, "some text that i'll pre-tokenize ù! * 12 j's ")
# Out:
# ['some',
#  ' text',
#  ' that',
#  ' i',
#  "'ll",
#  ' pre',
#  '-',
#  'tokenize',
#  ' ù',
#  '!',
#  ' *',
#  ' 12',
#  ' j',
#  "'s",
#  ' ']

# %%
f = 'marouane'
import regex as re
boundaries = [0,1,2,3]

# %%
len((1,2))
# Out:
# 2

# %%
d = {1:2, 3:4}

# %%
p = {(72, 105): 2, (78, 98): 1}

# %%
for i in b'abc':
    print(i)
# Out:
# 97
# 98
# 99

# %%
d = {(b'h', b'a'): 5, (b'n', b'j'): 5}

# %%
max(d, key=lambda k: (d[k], k[0], k[1]))
# Out:
# (b'n', b'j')

# %%
b'h' > b'e'
# Out:
# True
