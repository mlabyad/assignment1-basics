# %%
import regex as re
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
re.findall(PAT, "some text that i'll pre-tokenize ù! * 12 j's ")
# Out:
# ['some',
#  ' text',
#  ' that',
#  ' i',
#  "'ll",
#  ' pre',
#  '-',
#  'tokenize',
#  ' ù',
#  '!',
#  ' *',
#  ' 12',
#  ' j',
#  "'s",
#  ' ']

# %%
f = 'marouane'
import regex as re
boundaries = [0,1,2,3]

# %%
re.split("|".join(["a", "r", "ou"]), f)
# Out:
# ['m', '', '', '', 'ne']

# %%
chunks = []
for b in range(1, len(boundaries)):
    chunks.append((boundaries[b-1], boundaries[b]))

# %%
chunks
# Out:
# [(0, 1), (1, 2), (2, 3)]
